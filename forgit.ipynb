# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/colabpractice/tensorflow_practice
# !pwd
# !apt-get install tree
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/colabpractice/tensorflow_practice
# /gdrive/My Drive/colabpractice/tensorflow_practice

# %%
# !pip install python-dotenv
import os
from dotenv import load_dotenv

# 載入 .env 檔案
load_dotenv()

# 從 .env 讀取參數
git_email = os.getenv("GIT_EMAIL")
git_name = os.getenv("GIT_NAME")
# !git config --global user.email {git_email}
# !git config --global user.name {git_name}
# !git config --global user.email "$GIT_EMAIL"
# !git config --global user.name "$GIT_NAME"
# !git remote rm origin
# !git remote add origin https://roleecorn:$GIT_TOKEN@github.com/roleecorn/tensorflow_practice.git

# !git commit -a -m "classification_image"
# Out:
# ...
# [main d702b97] classification_image
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git add .

# %%
# !git commit -a -m "classification_image"

# %%
# !git config --global user.email "roleecorn@gmail.com"
# !git config --global user.name "roleecorn"
# !git commit -a -m "0306_update"
# Out:
# [main ee2e077] 0306_update
#  9 files changed, 214 insertions(+), 76 deletions(-)
#  rewrite sql.ipynb (99%)

# %%
# !git branch -M main
# !git push -u -f origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 335 bytes | 83.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/roleecorn/tensorflow_practice.git
#    7aa7751..d702b97  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git log   -L  --decorate   --graph
# !git log -h
# !git log --oneline  --graph
# Out:
# * 7e7b33e (HEAD -> main) backup0912
# * 76498fe (origin/main) improve_element
# * 024439a DBdone
# * 9a1cb66 gameChangeToDB
# * 836963e rankChangeToDB
# * a8b3f21 battleChangeToDB
# * 2d96229 changeToDb
# * 5825ef8 daily0719
# *   2928a61 Merge pull request #4 from Sun-I-Fu/main
# |\
# | * 7f4076d dbtest
# |/
# * 4d2eb29 daily0719
# *   6b4ce31 Merge pull request #3 from Sun-I-Fu/main
# |\
# | * 0f7b91f newdataform
# |/
# * b40ff63 daily0601
# * dda012e stamp_and_embed
# * 7ce6acd rankfix
# *   0aedf55 Merge pull request #2 from Sun-I-Fu/main
# |\
# | * 409c27a test
# |/
# * f56db95 rankfix
# * fe80087 rankfix
# * bc0889f 0526
# * 74e7729 0526
# * 053d0de try
# * e44dc87 colab-comit
